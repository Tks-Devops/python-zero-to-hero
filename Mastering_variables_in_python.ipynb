# %% [markdown]
# <a href="https://colab.research.google.com/github/Tks-Devops/python-zero-to-hero/blob/main/Mastering_variables_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #variables: container where we try to store any kind of value.
# # automatocally data type assignment

# %%
x = 2
y = 3
z = x + y

# %% [markdown]
# what is variable ?
# why variable was required ?
#
# # Data type variables in python
# # 1. int 2. float 3. string 4. boolean 5. complex

# %%
z
# Out:
# 5

# %%
type(z)
# Out:
# int

# %%
from typing_extensions import type_repr
a = 5.6
type(a)
# Out:
# float

# %%
b = "tk"
type(b)
# Out:
# str

# %%
c = True
type(c)
# Out:
# bool

# %%
d = 7 + 2j
type(d)
# Out:
# complex

# %%
d.real

#complexNUm plus the value which return in cpmlexnumber which is real or imaginery always return in float type
# Out:
# 7.0

# %%
d.imag
#retuen type of complex number for real or imaginery ans should always return  float type
# Out:
# 2.0

# %% [markdown]
# which ever variable in python which is case sensitive . it means upper charater and lower charater will react differently .

# %%
val1 = True #1
val2 = False #0

val1 - val2
# Out:
# 1

# %%
val1 * val2
# Out:
# 0

# %% [markdown]
# practice set
# 1. fevonaici seriose
# 2. palindrome
# 3. what is variable and why we need the variable.
# 4. characteristics of variable and how to check the datatypes pratically
# 5. discussed about the data types with its examples
