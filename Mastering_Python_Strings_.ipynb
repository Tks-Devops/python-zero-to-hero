# %% [markdown]
# <a href="https://colab.research.google.com/github/Tks-Devops/python-zero-to-hero/blob/main/Mastering_Python_Strings_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# String
#
# 1. str1 = T  u  l  a  s  i
#    -INDEX-        0  1  2  3  4  5
#
#
#
# *   str1(3) ans will be "a"
# *

# %%
# intialization of a string in python
str1 = "Tulasi"
str1[3]
# Out:
# 'a'

# %% [markdown]
# str1 = T u l a s i -negetive INDEX- -6 -5 -4 -3 -2 -1
# str1(-1) ans will be "i"

# %%
#indexing character in the string
# forword - 0 to n-1
# backword - -1 to -(n-1)
str1[-1]
# Out:
# 'i'

# %%
# length of the string
len(str1)
# Out:
# 6

# %%
# inbuild function of the string
str1.find("a")
# Out:
# 3

# %%
# if we use "find" function where if character is present the answer will return the exart index number or else if not presnt in a string return "-1"
str1.find("k")
# Out:
# -1

# %% [markdown]
# # what ever result will get using these inbuid function will get result/output always forword direction (return positive index in return only if charater are not present in the string then only we will get "-1").

# %%
# split function
# USED IN realtime where in  Natural Language Processing domain(textual data)..like sentimental data
text = "hello tulasi"
text.split()
# Out:
# ['hello', 'tulasi']

# %%
# REPLACE THE WORD "TULASI" TO "PYTHON"
text.replace("tulasi","python")
# Out:
# 'hello python'

# %%
# why this result will be "hello python" bcoz we not reassigned the value. just we replace that place .
print(text)
# Out:
# hello tulasi

# %%
# count function is used to count the given character
str2 = "Tulasi kumar sahu"
# how many time "a" appear in the str2
str2.count("a")
# Out:
# 3

# %%
# casesensitive
str2.count("T")
# Out:
# 0

# %%
str2.count("t")
# Out:
# 1

# %%
# conversion to lower case charater
str2.lower()
# Out:
# 'tulasi kumar sahu'

# %%
# conversion to upper case charater
str2.upper()
# Out:
# 'TULASI KUMAR SAHU'

# %%
# swap case--lowercase case convered upper and vice-versa
str2.swapcase()
# Out:
# 'tULASI KUMAR SAHU'

# %%
# titel( ) and capitalize()
str3 = "this is the mastering python strings masterclass attended by tulasi"
str3.title()
# Out:
# 'This Is The Mastering Python Strings Masterclass Attended By Tulasi'

# %%
str3.capitalize()
# this only capitalize first later of the sentances
# Out:
# 'This is the mastering python strings masterclass attended by tulasi'

# %%
#slicing
# last part not included in index
str1[0:3]
# Out:
# 'Tul'

# %%
# i want to print all the string but skip one  one character in between ...like i want to print 0 index then skip 1 then print 2 then skip 3 as so on
str1[0:6:2]
#1ST INDIACATE WHERE TO START AND MIDDLE ONE HOW MANY LATTERS AND LAST ONE HOW MANY WORD WNAT TO JUMP
# Out:
# 'Tls'

# %%
str1[::2]
#here no need to mension anything automate it will take
# Out:
# 'Tls'

# %%
# reversal a complete string
str1[5::-1]
# Out:
# 'isaluT'

# %%
str1[::-1]
# Out:
# 'isaluT'

# %%
#return - isa
str1[:1:-1]
# Out:
# 'isal'
